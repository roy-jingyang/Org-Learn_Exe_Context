# %%
import pandas as pd
import sklearn

# %%
df = pd.read_csv('bpic15_amended_typed.csv')

print(df['activity'].nunique())
print(df['Activity'].nunique())
print(df['CO'].nunique())

df
# Out:
# 118
# 154
# 12
#         Unnamed: 0  Unnamed: 0.1   Case ID  \
# 0                0             0   4284682
# 1                1             1   4511735
# 2                2             2   3090877
# 3                3             4   3871304
# 4                4             6   3007101
# ...            ...           ...       ...
# 193448      193448        262622  12751727
# 193449      193449        262624  12663845
# 193450      193450        262625  12999831
# 193451      193451        262626  12999831
# 193452      193452        262627   3256221
#
#                                              activity  Resource  \
# 0               enter senddate procedure confirmation    560852
# 1                    register submission date request   1254625
# 2               enter senddate procedure confirmation   3148844
# 3                             date for inspection MER    560532
# 4                    register submission date request    560749
# ...                                               ...       ...
# 193448  start decision phase decision permitting sent    560912
# 193449  start decision phase decision permitting sent    560912
# 193450  start decision phase decision permitting sent    560872
# 193451   enter senddate decision environmental permit    560872
# 193452               register submission date request    560462
#
#          Complete Timestamp              ct:last_phase  \
# 0       2009-11-18 09:00:00            Besluit genomen
# 1       2009-11-23 09:00:00  Vergunning onherroepelijk
# 2       2010-01-01 09:00:00        Vergunning verleend
# 3       2010-06-29 08:00:00       Procedure afgebroken
# 4       2010-10-04 08:00:00         Aanvraag ontvangen
# ...                     ...                        ...
# 193448  2015-03-05 09:00:00      Beschikking verzonden
# 193449  2015-03-05 09:00:00      Beschikking verzonden
# 193450  2015-03-09 09:00:00      Beschikking verzonden
# 193451  2015-03-09 09:00:00      Beschikking verzonden
# 193452  2015-08-01 08:00:00         Aanvraag ontvangen
#
#                                                case_parts         Activity  \
# 0                                              Bouw,Sloop   01_HOOFD_190_2
# 1                        Brandveilig gebruik (vergunning)     01_HOOFD_010
# 2                                     Milieu (vergunning)   01_HOOFD_065_2
# 3                                     Milieu (vergunning)     01_HOOFD_080
# 4                                     Milieu (vergunning)     01_HOOFD_010
# ...                                                   ...              ...
# 193448                                               Bouw  01_HOOFD_510_2a
# 193449                                               Bouw  01_HOOFD_510_2a
# 193450                                                Kap  01_HOOFD_510_2a
# 193451                                                Kap   01_HOOFD_510_2
# 193452  Bouw,Kap,Milieu (neutraal wijziging),Flora en ...     01_HOOFD_010
#
#        r:municipality ct:permit_type    at:phase tt:month  tt:day tt:weekday  \
# 0              muni-4           Bouw  01_HOOFD_1      Nov  Day_18        Wed
# 1              muni-5       Non Bouw  01_HOOFD_0      Nov  Day_23        Mon
# 2              muni-3       Non Bouw  01_HOOFD_0      Jan   Day_1        Fri
# 3              muni-2       Non Bouw  01_HOOFD_0      Jun  Day_29        Tue
# 4              muni-3       Non Bouw  01_HOOFD_0      Oct   Day_4        Mon
# ...               ...            ...         ...      ...     ...        ...
# 193448         muni-1           Bouw  01_HOOFD_5      Mar   Day_5        Thu
# 193449         muni-1           Bouw  01_HOOFD_5      Mar   Day_5        Thu
# 193450         muni-1       Non Bouw  01_HOOFD_5      Mar   Day_9        Mon
# 193451         muni-1       Non Bouw  01_HOOFD_5      Mar   Day_9        Mon
# 193452         muni-1           Bouw  01_HOOFD_0      Aug   Day_1        Sat
#
#        tt:ampm  CT       AT         TT                      CO
# 0           AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 1           AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 2           AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 3           AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 4           AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# ...        ...  ..      ...        ...                     ...
# 193448      AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 193449      AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 193450      AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 193451      AM NaN  0-1-4-5  M-T-W-T-F  null/0-1-4-5/M-T-W-T-F
# 193452      AM NaN  0-1-4-5        Sat        null/0-1-4-5/Sat
#
# [193453 rows x 20 columns]

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from math import log

X1 = df.groupby(['Resource', 'Activity']).size().unstack().fillna(0)
X2 = df.groupby(['Resource', 'CO']).size().unstack().fillna(0)
#X = X.applymap(lambda x: log(x + 1))

best_k = -1
best_score = -2

# for k in range(2, len(X)):
#     clu = AgglomerativeClustering(n_clusters=k).fit_predict(X)
#     ss = silhouette_score(X, clu)
#     if ss > best_score:
#         best_score = ss
#         best_k = k
# print(best_k)

# clu = AgglomerativeClustering(n_clusters=best_k).fit_predict(X)
# print(best_k)
# print(silhouette_score(X, clu))

l_ss1 = []
l_ss2 = []
for k in range(2, len(X1)):
    clu1 = AgglomerativeClustering(n_clusters=k).fit_predict(X1)
    ss1 = silhouette_score(X1, clu1)
    l_ss1.append(ss1)
    clu2 = AgglomerativeClustering(n_clusters=k).fit_predict(X2)
    ss2 = silhouette_score(X2, clu2)
    l_ss2.append(ss2)

data = []
for i in range(len(l_ss1)):
    data.append({'k': i + 2, 'score': l_ss2[i], 'matrix based on': 'Execution Context'})
    data.append({'k': i + 2, 'score': l_ss1[i], 'matrix based on': 'Activity'})

data = pd.DataFrame(data)

data
# Out:
#       k     score    matrix based on
# 0     2  0.715024  Execution Context
# 1     2  0.610249           Activity
# 2     3  0.725547  Execution Context
# 3     3  0.643522           Activity
# 4     4  0.724483  Execution Context
# ..   ..       ...                ...
# 133  68  0.022804           Activity
# 134  69  0.042254  Execution Context
# 135  69  0.013330           Activity
# 136  70  0.000000  Execution Context
# 137  70  0.006182           Activity
#
# [138 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8, 4))
ax = sns.lineplot(data=data, x="k", y="score", ax=ax, hue="matrix based on", style='matrix based on')
plt.xlabel('Number of resource clusters')
plt.ylabel("Silhouette score")
plt.show()
f.savefig("plot2.pdf", bbox_inches='tight')
