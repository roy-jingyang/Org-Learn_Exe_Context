# %%
import pandas as pd

df = pd.read_csv('bpic-15_hmean.csv')

import numpy as np
from numpy import matlib
curve_cvx = list(df['hmean'])[2:8]
curve_ccv = list(df['hmean'])[:10]

print(curve_cvx)
print(curve_ccv)

# print(curve)
# print(len(curve))
idx_curve_cvx = list(range(1, len(curve_cvx) + 1))
idx_curve_ccv = list(range(1, len(curve_ccv) + 1))
#print(len(idx_curve))
# Out:
# [0.016014358, 0.077498194, 0.200587407, 0.297859588, 0.386275836]
# [0.000309952, 0.001690569, 0.007178096, 0.016014358, 0.077498194, 0.200587407, 0.297859588, 0.386275836, 0.445683657, 0.501581222]

# %%
from kneed import KneeLocator

kl = KneeLocator(idx_curve_cvx, curve_cvx, curve='convex')
#kl = KneeLocator(idx_curve_ccv, curve_ccv, curve='concave')

kl.plot_knee()
# Out:
# /home/yjingasd/miniconda3/envs/orgmining/lib/python3.9/site-packages/kneed/knee_locator.py:304: UserWarning: No knee/elbow found
#   warnings.warn("No knee/elbow found")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_337647/382222426.py in <module>
#       4 #kl = KneeLocator(idx_curve_ccv, curve_ccv, curve='concave')
#       5
# ----> 6 kl.plot_knee()
#
# ~/miniconda3/envs/orgmining/lib/python3.9/site-packages/kneed/knee_locator.py in plot_knee(self, figsize)
#     355         plt.title("Knee Point")
#     356         plt.plot(self.x, self.y, "b", label="data")
# --> 357         plt.vlines(
#     358             self.knee, plt.ylim()[0], plt.ylim()[1], linestyles="--", label="knee/elbow"
#     359         )
#
# ~/miniconda3/envs/orgmining/lib/python3.9/site-packages/matplotlib/pyplot.py in vlines(x, ymin, ymax, colors, linestyles, label, data, **kwargs)
#    3259         x, ymin, ymax, colors=None, linestyles='solid', label='', *,
#    3260         data=None, **kwargs):
# -> 3261     return gca().vlines(
#    3262         x, ymin, ymax, colors=colors, linestyles=linestyles,
#    3263         label=label, **({"data": data} if data is not None else {}),
#
# ~/miniconda3/envs/orgmining/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/envs/orgmining/lib/python3.9/site-packages/matplotlib/axes/_axes.py in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1127
#    1128             corners = (minx, miny), (maxx, maxy)
# -> 1129             self.update_datalim(corners)
#    1130             self._request_autoscale_view()
#    1131
#
# ~/miniconda3/envs/orgmining/lib/python3.9/site-packages/matplotlib/axes/_base.py in update_datalim(self, xys, updatex, updatey)
#    2282         """
#    2283         xys = np.asarray(xys)
# -> 2284         if not np.any(np.isfinite(xys)):
#    2285             return
#    2286         self.dataLim.update_from_data_xy(xys, self.ignore_existing_data_limits,
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
