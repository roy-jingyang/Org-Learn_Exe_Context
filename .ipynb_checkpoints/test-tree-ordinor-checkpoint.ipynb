# %%
import numpy as np
import pandas as pd

from ordinor.io import read_disco_csv

# %%
el = read_disco_csv('data/processed/wabo.csv')
# el = read_disco_csv('data/processed/bpic15.csv')
# el = read_disco_csv('data/processed/bpic17.csv')

print(len(pd.unique(el['org:resource'])))
print(len(pd.unique(el['concept:name'])))
# Out:
# Importing from CSV file data/processed/wabo.csv
# Scanned 6641 events from "data/processed/wabo.csv".
# --------------------------------------------------------------------------------
# Number of events:		6641
# Number of cases:		1348
# --------------------------------------------------------------------------------
# 44
# 27

# %%
# specification

all_cand_attrs = [
    # WABO
    {'attr': 'ct:channel', 'attr_type': 'categorical', 'attr_dim': 'CT'},
    {'attr': 'tt:weekday', 'attr_type': 'categorical', 'attr_dim': 'TT'}, 
    {'attr': 'tt:ampm', 'attr_type': 'categorical', 'attr_dim': 'TT'},
    
    # BPIC15
#     {'attr': 'ct:permit_type', 'attr_type': 'categorical', 'attr_dim': 'CT'},
#     {'attr': 'tt:weekday', 'attr_type': 'categorical', 'attr_dim': 'TT'}, 
#     {'attr': 'tt:ampm', 'attr_type': 'categorical', 'attr_dim': 'TT'},
    
    # BPIC17
#     {'attr': 'ct:loan_goal', 'attr_type': 'categorical', 'attr_dim': 'CT'},
#     {'attr': 'ct:application_type', 'attr_type': 'categorical', 'attr_dim': 'CT'},
#     {'attr': 'ct:requested_amount', 'attr_type': 'numeric', 'attr_dim': 'CT'},
#     {'attr': 'at:event_origin', 'attr_type': 'categorical', 'attr_dim': 'AT'},
#     {'attr': 'tt:weekday', 'attr_type': 'categorical', 'attr_dim': 'TT'}, 
#     {'attr': 'tt:ampm', 'attr_type': 'categorical', 'attr_dim': 'TT'},
]

spec = dict()
spec['cand_attrs'] = all_cand_attrs

# %%
from ordinor.execution_context import ODTMiner, ODTSAMiner
from sklearn.model_selection import KFold
from copy import deepcopy
kf = KFold(n_splits=5, shuffle=True)

# %%
RUN_CV = False

if RUN_CV:
    i = 0
    for train_index, test_index in kf.split(el):
        i += 1
        el_train = el.loc[train_index]
        el_test = el.loc[test_index]

        miner = ODTMiner(el_train, spec, eps=1e-2)

        el_test_agg = []
        for node_label, node in miner._leaves.items():
            el_test_par = deepcopy(node.composite_rule.apply(el_test))
            el_test_par['case_type'] = node.ct_label
            el_test_par['activity_type'] = node.at_label
            el_test_par['time_type'] = node.tt_label

            el_test_agg.append(el_test_par[['org:resource', 'case_type', 'activity_type', 'time_type']])
        pd.concat(el_test_agg).to_csv(f"5fold_{i}.csv")
else:
    miner = ODTMiner(el, spec, eps=1e-2)
# Out:
# Decision tree initialized with an empty root node
# 	Dis. = 0.000000, Imp. = 1.000000, Target = 1.000000
# Start to fit decision tree with epsilon = 0.01
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.257169, Imp. = 0.979428, Target = 1.020572
# Tree grows by splitting all current leaf nodes on `tt:ampm`
# 	Dis. = 0.403828, Imp. = 0.965586, Target = 0.584413
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.292868, Imp. = 0.951931, Target = 0.288912
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.305735, Imp. = 0.945681, Target = 0.050500
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.305797, Imp. = 0.945004, Target = 0.000917
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.309197, Imp. = 0.938643, Target = 0.017850
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.406302, Imp. = 0.920794, Target = 0.333071
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.469357, Imp. = 0.901394, Target = 0.176261
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.488813, Imp. = 0.875202, Target = 0.070510
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.488829, Imp. = 0.874751, Target = 0.000548
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.491823, Imp. = 0.866338, Target = 0.015742
# No further split can be performed.
# Procedure stopped with final scores:
# ********************************************************************************
# ============================== TREE SUMMARY ==============================
# Current scores:	Dis. = 0.491823, Imp. = 0.866338, Target = 0.015742
# ============================== LEAF NODES ==============================
# 5312 events were partitioned into 44 leaf nodes:
# Node [585]: (CT=330, AT=0, TT=115), containing 55 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[115](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [586]: (CT=331, AT=0, TT=115), containing 23 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[115](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [202]: (CT=60, AT=0, TT=115), containing 821 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[115](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [203]: (CT=60, AT=0, TT=117), containing 2 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[117](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [205]: (CT=60, AT=0, TT=119), containing 2 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[119](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [206]: (CT=60, AT=0, TT=120), containing 2 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[120](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [587]: (CT=330, AT=0, TT=143), containing 9 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[143](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [588]: (CT=331, AT=0, TT=143), containing 4 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[143](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [251]: (CT=60, AT=0, TT=145), containing 5 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[145](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [254]: (CT=60, AT=0, TT=143), containing 87 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[143](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [589]: (CT=330, AT=0, TT=174), containing 85 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[174](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [590]: (CT=331, AT=0, TT=174), containing 19 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[174](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [591]: (CT=330, AT=0, TT=176), containing 11 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[176](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [592]: (CT=331, AT=0, TT=176), containing 1 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[176](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [310]: (CT=60, AT=0, TT=174), containing 841 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[174](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [314]: (CT=60, AT=0, TT=176), containing 115 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[176](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [593]: (CT=330, AT=0, TT=209), containing 77 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[209](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [594]: (CT=331, AT=0, TT=209), containing 53 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[209](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [595]: (CT=330, AT=0, TT=211), containing 10 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[211](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [596]: (CT=331, AT=0, TT=211), containing 9 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[211](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [383]: (CT=60, AT=0, TT=209), containing 937 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[209](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [387]: (CT=60, AT=0, TT=211), containing 92 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[211](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [597]: (CT=330, AT=0, TT=244), containing 46 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[244](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [598]: (CT=331, AT=0, TT=244), containing 28 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[244](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [599]: (CT=330, AT=0, TT=245), containing 67 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[245](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [600]: (CT=331, AT=0, TT=245), containing 38 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[245](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [601]: (CT=330, AT=0, TT=246), containing 18 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[246](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [602]: (CT=331, AT=0, TT=246), containing 1 events.
# 	CT=[331](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[246](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [603]: (CT=330, AT=0, TT=247), containing 19 events.
# 	CT=[330](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[247](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [468]: (CT=60, AT=0, TT=244), containing 568 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[244](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [469]: (CT=60, AT=0, TT=245), containing 962 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[245](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [472]: (CT=60, AT=0, TT=246), containing 144 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[246](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [473]: (CT=60, AT=0, TT=247), containing 80 events.
# 	CT=[60](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[247](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [536]: (CT=281, AT=0, TT=115), containing 12 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[115](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [537]: (CT=281, AT=0, TT=143), containing 1 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[143](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [538]: (CT=283, AT=0, TT=174), containing 2 events.
# 	CT=[283](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[174](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [539]: (CT=281, AT=0, TT=174), containing 24 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[174](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [540]: (CT=281, AT=0, TT=209), containing 20 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[209](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [541]: (CT=281, AT=0, TT=211), containing 1 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[211](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [542]: (CT=281, AT=0, TT=244), containing 3 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[244](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [543]: (CT=283, AT=0, TT=245), containing 1 events.
# 	CT=[283](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[245](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [544]: (CT=281, AT=0, TT=245), containing 14 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[245](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [545]: (CT=281, AT=0, TT=246), containing 2 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[246](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [546]: (CT=281, AT=0, TT=247), containing 1 events.
# 	CT=[281](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[247](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# ========================= ENCODING TYPES WITH RULES =========================
# Rules for Case Types:
# 	(`ct:channel` ∈ {'Desk'})
# 	(`ct:channel` ∈ {'Post'})
# 	(`ct:channel` ∈ {'Internet'})
# 	(`ct:channel` ∈ {'e-mail'})
# 	(`ct:channel` ∈ {'Intern'})
# Rules for Activity Types:
# 	⊥ (null)
# Rules for Time Types:
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# ********************************************************************************
# --------------------------------------------------------------------------------
# Count of Types in the current ODTMiner:
# Number of C Types:		5
# Number of A Types:		1
# Number of T Types:		14
# --------------------------------------------------------------------------------
# Decision tree initialized with an empty root node
# 	Dis. = 0.000000, Imp. = 1.000000, Target = 1.000000
# Start to fit decision tree with epsilon = 0.01
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.324777, Imp. = 0.977762, Target = 1.022238
# Tree grows by splitting all current leaf nodes on `tt:ampm`
# 	Dis. = 0.439191, Imp. = 0.958731, Target = 0.371747
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.310097, Imp. = 0.941998, Target = 0.311388
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.322885, Imp. = 0.936084, Target = 0.047515
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.323040, Imp. = 0.934818, Target = 0.001835
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.323501, Imp. = 0.927560, Target = 0.009190
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.432168, Imp. = 0.907894, Target = 0.357112
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.465963, Imp. = 0.891959, Target = 0.095751
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.488733, Imp. = 0.875280, Target = 0.067566
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.488751, Imp. = 0.874827, Target = 0.000553
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.491797, Imp. = 0.866193, Target = 0.016101
# No further split can be performed.
# Procedure stopped with final scores:
# ********************************************************************************
# ============================== TREE SUMMARY ==============================
# Current scores:	Dis. = 0.491797, Imp. = 0.866193, Target = 0.016101
# ============================== LEAF NODES ==============================
# 5313 events were partitioned into 43 leaf nodes:
# Node [234]: (CT=69, AT=0, TT=130), containing 1 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[130](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [237]: (CT=69, AT=0, TT=133), containing 4 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[133](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [665]: (CT=359, AT=0, TT=177), containing 59 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [666]: (CT=360, AT=0, TT=177), containing 37 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [667]: (CT=359, AT=0, TT=178), containing 18 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [668]: (CT=359, AT=0, TT=179), containing 13 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[179](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [669]: (CT=360, AT=0, TT=179), containing 3 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[179](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [312]: (CT=69, AT=0, TT=177), containing 1013 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [313]: (CT=69, AT=0, TT=181), containing 5 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[181](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [315]: (CT=69, AT=0, TT=178), containing 79 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [316]: (CT=69, AT=0, TT=179), containing 87 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[179](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [670]: (CT=359, AT=0, TT=264), containing 53 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[264](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [671]: (CT=360, AT=0, TT=264), containing 28 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[264](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [672]: (CT=359, AT=0, TT=265), containing 75 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[265](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [673]: (CT=360, AT=0, TT=265), containing 61 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[265](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [674]: (CT=359, AT=0, TT=266), containing 9 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[266](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [675]: (CT=360, AT=0, TT=266), containing 8 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[266](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [471]: (CT=69, AT=0, TT=264), containing 813 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[264](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [472]: (CT=69, AT=0, TT=265), containing 907 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[265](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [475]: (CT=69, AT=0, TT=271), containing 1 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[271](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [476]: (CT=69, AT=0, TT=266), containing 96 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[266](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [676]: (CT=359, AT=0, TT=296), containing 50 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[296](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [677]: (CT=360, AT=0, TT=296), containing 24 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[296](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [678]: (CT=359, AT=0, TT=297), containing 77 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[297](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [679]: (CT=360, AT=0, TT=297), containing 20 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[297](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [680]: (CT=359, AT=0, TT=298), containing 15 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[298](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [681]: (CT=360, AT=0, TT=298), containing 1 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[298](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [682]: (CT=359, AT=0, TT=299), containing 16 events.
# 	CT=[359](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[299](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [683]: (CT=360, AT=0, TT=299), containing 2 events.
# 	CT=[360](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[299](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [552]: (CT=69, AT=0, TT=296), containing 564 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[296](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [553]: (CT=69, AT=0, TT=297), containing 825 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[297](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [556]: (CT=69, AT=0, TT=298), containing 152 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[298](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [557]: (CT=69, AT=0, TT=299), containing 115 events.
# 	CT=[69](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[299](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [617]: (CT=311, AT=0, TT=177), containing 1 events.
# 	CT=[311](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [618]: (CT=312, AT=0, TT=177), containing 13 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [619]: (CT=312, AT=0, TT=179), containing 1 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[179](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [620]: (CT=312, AT=0, TT=264), containing 12 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[264](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [621]: (CT=312, AT=0, TT=265), containing 20 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[265](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [622]: (CT=312, AT=0, TT=266), containing 1 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[266](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [623]: (CT=312, AT=0, TT=296), containing 4 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[296](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [624]: (CT=311, AT=0, TT=297), containing 2 events.
# 	CT=[311](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[297](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [625]: (CT=312, AT=0, TT=297), containing 25 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[297](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [626]: (CT=312, AT=0, TT=298), containing 3 events.
# 	CT=[312](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[298](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# ========================= ENCODING TYPES WITH RULES =========================
# Rules for Case Types:
# 	(`ct:channel` ∈ {'Internet'})
# 	(`ct:channel` ∈ {'Desk'})
# 	(`ct:channel` ∈ {'Post'})
# 	(`ct:channel` ∈ {'Intern'})
# 	(`ct:channel` ∈ {'e-mail'})
# Rules for Activity Types:
# 	⊥ (null)
# Rules for Time Types:
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# ********************************************************************************
# --------------------------------------------------------------------------------
# Count of Types in the current ODTMiner:
# Number of C Types:		5
# Number of A Types:		1
# Number of T Types:		14
# --------------------------------------------------------------------------------
# Decision tree initialized with an empty root node
# 	Dis. = 0.000000, Imp. = 1.000000, Target = 1.000000
# Start to fit decision tree with epsilon = 0.01
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.292134, Imp. = 0.974877, Target = 1.025123
# Tree grows by splitting all current leaf nodes on `tt:ampm`
# 	Dis. = 0.425774, Imp. = 0.957904, Target = 0.474872
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.278267, Imp. = 0.943709, Target = 0.361263
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.278793, Imp. = 0.943085, Target = 0.002552
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.319178, Imp. = 0.933529, Target = 0.154989
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.319828, Imp. = 0.929402, Target = 0.006455
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.320032, Imp. = 0.928083, Target = 0.002059
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.390348, Imp. = 0.908171, Target = 0.241169
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.391188, Imp. = 0.901356, Target = 0.009658
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.455908, Imp. = 0.881919, Target = 0.187007
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.491634, Imp. = 0.865492, Target = 0.096990
# No further split can be performed.
# Procedure stopped with final scores:
# ********************************************************************************
# ============================== TREE SUMMARY ==============================
# Current scores:	Dis. = 0.491634, Imp. = 0.865492, Target = 0.096990
# ============================== LEAF NODES ==============================
# 5313 events were partitioned into 43 leaf nodes:
# Node [314]: (CT=29, AT=0, TT=215), containing 65 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[215](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [315]: (CT=29, AT=0, TT=216), containing 21 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[216](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [316]: (CT=49, AT=0, TT=215), containing 1 events.
# 	CT=[49](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[215](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [317]: (CT=71, AT=0, TT=215), containing 976 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[215](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [318]: (CT=71, AT=0, TT=219), containing 2 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[219](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [319]: (CT=71, AT=0, TT=216), containing 71 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[216](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [320]: (CT=71, AT=0, TT=221), containing 4 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[221](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [321]: (CT=93, AT=0, TT=215), containing 35 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[215](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [322]: (CT=94, AT=0, TT=215), containing 14 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[215](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [323]: (CT=94, AT=0, TT=216), containing 1 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[216](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [424]: (CT=29, AT=0, TT=325), containing 49 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[325](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [425]: (CT=29, AT=0, TT=326), containing 13 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[326](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [426]: (CT=29, AT=0, TT=327), containing 10 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[327](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [427]: (CT=71, AT=0, TT=325), containing 576 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[325](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [428]: (CT=71, AT=0, TT=329), containing 5 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[329](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [429]: (CT=71, AT=0, TT=326), containing 154 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[326](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [430]: (CT=71, AT=0, TT=327), containing 80 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[327](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [431]: (CT=93, AT=0, TT=325), containing 25 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[325](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [432]: (CT=94, AT=0, TT=325), containing 6 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[325](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [433]: (CT=93, AT=0, TT=326), containing 1 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[326](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [434]: (CT=93, AT=0, TT=327), containing 4 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[327](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [435]: (CT=94, AT=0, TT=326), containing 2 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[326](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [436]: (CT=94, AT=0, TT=327), containing 2 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[327](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [506]: (CT=29, AT=0, TT=407), containing 62 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[407](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [507]: (CT=29, AT=0, TT=408), containing 72 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[408](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [468]: (CT=29, AT=0, TT=369), containing 77 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[369](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [508]: (CT=29, AT=0, TT=409), containing 9 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[409](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [470]: (CT=29, AT=0, TT=371), containing 14 events.
# 	CT=[29](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[371](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [471]: (CT=49, AT=0, TT=369), containing 2 events.
# 	CT=[49](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[369](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [509]: (CT=71, AT=0, TT=407), containing 811 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[407](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [510]: (CT=71, AT=0, TT=408), containing 933 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[408](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [473]: (CT=71, AT=0, TT=369), containing 833 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[369](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [511]: (CT=71, AT=0, TT=412), containing 1 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[412](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [512]: (CT=71, AT=0, TT=409), containing 93 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[409](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [475]: (CT=71, AT=0, TT=371), containing 121 events.
# 	CT=[71](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[371](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [513]: (CT=93, AT=0, TT=407), containing 28 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[407](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [514]: (CT=93, AT=0, TT=408), containing 60 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[408](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [477]: (CT=93, AT=0, TT=369), containing 22 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[369](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [515]: (CT=94, AT=0, TT=407), containing 8 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[407](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [516]: (CT=94, AT=0, TT=408), containing 17 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[408](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [479]: (CT=94, AT=0, TT=369), containing 23 events.
# 	CT=[94](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[369](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [517]: (CT=93, AT=0, TT=409), containing 9 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[409](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [481]: (CT=93, AT=0, TT=371), containing 1 events.
# 	CT=[93](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[371](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# ========================= ENCODING TYPES WITH RULES =========================
# Rules for Case Types:
# 	(`ct:channel` ∈ {'Desk'})
# 	(`ct:channel` ∈ {'Intern'})
# 	(`ct:channel` ∈ {'Internet'})
# 	(`ct:channel` ∈ {'Post'})
# 	(`ct:channel` ∈ {'e-mail'})
# Rules for Activity Types:
# 	⊥ (null)
# Rules for Time Types:
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# ********************************************************************************
# --------------------------------------------------------------------------------
# Count of Types in the current ODTMiner:
# Number of C Types:		5
# Number of A Types:		1
# Number of T Types:		14
# --------------------------------------------------------------------------------
# Decision tree initialized with an empty root node
# 	Dis. = 0.000000, Imp. = 1.000000, Target = 1.000000
# Start to fit decision tree with epsilon = 0.01
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.290456, Imp. = 0.974308, Target = 1.025692
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.583079, Imp. = 0.963033, Target = 1.019036
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.382055, Imp. = 0.946450, Target = 0.361982
# Tree grows by splitting all current leaf nodes on `tt:ampm`
# 	Dis. = 0.415450, Imp. = 0.920290, Target = 0.115049
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.426505, Imp. = 0.914597, Target = 0.032796
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.450898, Imp. = 0.897690, Target = 0.075678
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.453912, Imp. = 0.890345, Target = 0.014868
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.454075, Imp. = 0.889393, Target = 0.001429
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.454968, Imp. = 0.882127, Target = 0.010135
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.489388, Imp. = 0.865107, Target = 0.094947
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.489468, Imp. = 0.864445, Target = 0.000931
# No further split can be performed.
# Procedure stopped with final scores:
# ********************************************************************************
# ============================== TREE SUMMARY ==============================
# Current scores:	Dis. = 0.489468, Imp. = 0.864445, Target = 0.000931
# ============================== LEAF NODES ==============================
# 5313 events were partitioned into 43 leaf nodes:
# Node [239]: (CT=101, AT=0, TT=99), containing 977 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[99](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [240]: (CT=102, AT=0, TT=99), containing 11 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[99](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [241]: (CT=101, AT=0, TT=100), containing 82 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[100](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [242]: (CT=102, AT=0, TT=100), containing 1 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[100](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [410]: (CT=165, AT=0, TT=99), containing 65 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[99](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [677]: (CT=254, AT=0, TT=99), containing 34 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[99](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [678]: (CT=255, AT=0, TT=99), containing 1 events.
# 	CT=[255](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[99](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [412]: (CT=165, AT=0, TT=100), containing 16 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[100](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [511]: (CT=101, AT=0, TT=314), containing 1 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[314](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [512]: (CT=101, AT=0, TT=315), containing 831 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[315](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [513]: (CT=102, AT=0, TT=315), containing 19 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[315](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [514]: (CT=101, AT=0, TT=317), containing 3 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[317](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [515]: (CT=101, AT=0, TT=318), containing 114 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[318](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [516]: (CT=165, AT=0, TT=315), containing 78 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[315](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [679]: (CT=254, AT=0, TT=315), containing 23 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[315](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [680]: (CT=255, AT=0, TT=315), containing 3 events.
# 	CT=[255](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[315](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [518]: (CT=165, AT=0, TT=318), containing 15 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[318](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [681]: (CT=254, AT=0, TT=318), containing 2 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[318](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [588]: (CT=101, AT=0, TT=373), containing 573 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[373](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [589]: (CT=101, AT=0, TT=374), containing 5 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[374](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [590]: (CT=102, AT=0, TT=373), containing 5 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[373](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [591]: (CT=101, AT=0, TT=376), containing 161 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[376](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [592]: (CT=101, AT=0, TT=377), containing 87 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[377](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [593]: (CT=102, AT=0, TT=376), containing 2 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[376](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [594]: (CT=102, AT=0, TT=377), containing 2 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[377](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [595]: (CT=165, AT=0, TT=373), containing 48 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[373](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [682]: (CT=254, AT=0, TT=373), containing 24 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[373](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [597]: (CT=165, AT=0, TT=376), containing 18 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[376](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [598]: (CT=165, AT=0, TT=377), containing 13 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[377](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [683]: (CT=254, AT=0, TT=377), containing 4 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[377](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [644]: (CT=101, AT=0, TT=411), containing 804 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[411](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [645]: (CT=101, AT=0, TT=412), containing 936 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[412](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [646]: (CT=102, AT=0, TT=411), containing 9 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[411](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [647]: (CT=102, AT=0, TT=412), containing 19 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[412](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [648]: (CT=101, AT=0, TT=415), containing 2 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[415](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [649]: (CT=101, AT=0, TT=416), containing 98 events.
# 	CT=[101](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[416](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [650]: (CT=102, AT=0, TT=416), containing 1 events.
# 	CT=[102](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[416](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [651]: (CT=165, AT=0, TT=411), containing 60 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[411](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [652]: (CT=165, AT=0, TT=412), containing 70 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[412](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [684]: (CT=254, AT=0, TT=411), containing 20 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[411](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [685]: (CT=254, AT=0, TT=412), containing 59 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[412](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [655]: (CT=165, AT=0, TT=416), containing 8 events.
# 	CT=[165](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[416](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [686]: (CT=254, AT=0, TT=416), containing 9 events.
# 	CT=[254](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[416](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# ========================= ENCODING TYPES WITH RULES =========================
# Rules for Case Types:
# 	(`ct:channel` ∈ {'Internet'})
# 	(`ct:channel` ∈ {'e-mail'})
# 	(`ct:channel` ∈ {'Desk'})
# 	(`ct:channel` ∈ {'Post'})
# 	(`ct:channel` ∈ {'Intern'})
# Rules for Activity Types:
# 	⊥ (null)
# Rules for Time Types:
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# ********************************************************************************
# --------------------------------------------------------------------------------
# Count of Types in the current ODTMiner:
# Number of C Types:		5
# Number of A Types:		1
# Number of T Types:		14
# --------------------------------------------------------------------------------
# Decision tree initialized with an empty root node
# 	Dis. = 0.000000, Imp. = 1.000000, Target = 1.000000
# Start to fit decision tree with epsilon = 0.01
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.278614, Imp. = 0.979228, Target = 1.020772
# Tree grows by splitting all current leaf nodes on `tt:ampm`
# 	Dis. = 0.418208, Imp. = 0.963965, Target = 0.516616
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.313166, Imp. = 0.946510, Target = 0.269279
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.313211, Imp. = 0.944594, Target = 0.002169
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.429019, Imp. = 0.921730, Target = 0.393949
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.429428, Imp. = 0.920448, Target = 0.002344
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.464192, Imp. = 0.897312, Target = 0.106090
# Tree grows by splitting all current leaf nodes on `tt:weekday`
# 	Dis. = 0.489902, Imp. = 0.881941, Target = 0.072517
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.490336, Imp. = 0.881371, Target = 0.001533
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.493974, Imp. = 0.872558, Target = 0.017419
# Tree grows by splitting all current leaf nodes on `ct:channel`
# 	Dis. = 0.495208, Imp. = 0.864448, Target = 0.011791
# No further split can be performed.
# Procedure stopped with final scores:
# ********************************************************************************
# ============================== TREE SUMMARY ==============================
# Current scores:	Dis. = 0.495208, Imp. = 0.864448, Target = 0.011791
# ============================== LEAF NODES ==============================
# 5313 events were partitioned into 43 leaf nodes:
# Node [515]: (CT=307, AT=0, TT=81), containing 803 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[81](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [516]: (CT=307, AT=0, TT=83), containing 4 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[83](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [517]: (CT=307, AT=0, TT=85), containing 2 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[85](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [518]: (CT=307, AT=0, TT=84), containing 95 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[84](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [519]: (CT=307, AT=0, TT=141), containing 2 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[141](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [520]: (CT=307, AT=0, TT=144), containing 3 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[144](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# Node [521]: (CT=307, AT=0, TT=177), containing 972 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [522]: (CT=307, AT=0, TT=178), containing 806 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [523]: (CT=315, AT=0, TT=178), containing 3 events.
# 	CT=[315](`ct:channel` ∈ {'Intern'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [524]: (CT=307, AT=0, TT=181), containing 80 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[181](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [525]: (CT=307, AT=0, TT=182), containing 115 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[182](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [526]: (CT=307, AT=0, TT=201), containing 563 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[201](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [527]: (CT=307, AT=0, TT=202), containing 935 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[202](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [528]: (CT=307, AT=0, TT=205), containing 161 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[205](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [529]: (CT=307, AT=0, TT=206), containing 101 events.
# 	CT=[307](`ct:channel` ∈ {'Internet'})
# 	AT=[0]⊥ (null)
# 	TT=[206](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [625]: (CT=417, AT=0, TT=81), containing 58 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[81](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [626]: (CT=418, AT=0, TT=81), containing 11 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[81](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [569]: (CT=361, AT=0, TT=81), containing 25 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[81](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# Node [627]: (CT=417, AT=0, TT=84), containing 11 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[84](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [628]: (CT=418, AT=0, TT=84), containing 2 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[84](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [571]: (CT=361, AT=0, TT=84), containing 1 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[84](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# Node [629]: (CT=417, AT=0, TT=177), containing 68 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [630]: (CT=418, AT=0, TT=177), containing 16 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [573]: (CT=361, AT=0, TT=177), containing 36 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[177](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [631]: (CT=417, AT=0, TT=178), containing 83 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [632]: (CT=418, AT=0, TT=178), containing 21 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [575]: (CT=361, AT=0, TT=178), containing 24 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[178](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [633]: (CT=417, AT=0, TT=181), containing 18 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[181](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [634]: (CT=418, AT=0, TT=181), containing 1 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[181](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# Node [635]: (CT=417, AT=0, TT=182), containing 16 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[182](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [578]: (CT=361, AT=0, TT=182), containing 2 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[182](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# Node [636]: (CT=417, AT=0, TT=201), containing 51 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[201](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [637]: (CT=418, AT=0, TT=201), containing 6 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[201](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [580]: (CT=361, AT=0, TT=201), containing 23 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[201](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [638]: (CT=417, AT=0, TT=202), containing 78 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[202](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [639]: (CT=418, AT=0, TT=202), containing 20 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[202](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [582]: (CT=361, AT=0, TT=202), containing 55 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[202](`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [640]: (CT=417, AT=0, TT=205), containing 20 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[205](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [641]: (CT=418, AT=0, TT=205), containing 3 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[205](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [584]: (CT=361, AT=0, TT=205), containing 1 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[205](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# Node [642]: (CT=417, AT=0, TT=206), containing 8 events.
# 	CT=[417](`ct:channel` ∈ {'Desk'})
# 	AT=[0]⊥ (null)
# 	TT=[206](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [643]: (CT=418, AT=0, TT=206), containing 1 events.
# 	CT=[418](`ct:channel` ∈ {'e-mail'})
# 	AT=[0]⊥ (null)
# 	TT=[206](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# Node [586]: (CT=361, AT=0, TT=206), containing 9 events.
# 	CT=[361](`ct:channel` ∈ {'Post'})
# 	AT=[0]⊥ (null)
# 	TT=[206](`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# ========================= ENCODING TYPES WITH RULES =========================
# Rules for Case Types:
# 	(`ct:channel` ∈ {'Internet'})
# 	(`ct:channel` ∈ {'Intern'})
# 	(`ct:channel` ∈ {'Desk'})
# 	(`ct:channel` ∈ {'e-mail'})
# 	(`ct:channel` ∈ {'Post'})
# Rules for Activity Types:
# 	⊥ (null)
# Rules for Time Types:
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Mon'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sat'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Sun'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Thu'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Wed'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'PM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Fri'})
# 	(`tt:ampm` ∈ {'AM'}) ∧ (`tt:weekday` ∈ {'Tue'})
# ********************************************************************************
# --------------------------------------------------------------------------------
# Count of Types in the current ODTMiner:
# Number of C Types:		5
# Number of A Types:		1
# Number of T Types:		14
# --------------------------------------------------------------------------------

# %%
if not RUN_CV:
    rl = miner.derive_resource_log(el)

    print('CT types: {}'.format(len(pd.unique(rl['case_type']))))
    print('AT types: {}'.format(len(pd.unique(rl['activity_type']))))
    print('TT types: {}'.format(len(pd.unique(rl['time_type']))))

    print(rl)

    for co, events in rl.groupby(['case_type', 'activity_type', 'time_type']):
        print(co)
        print('\t', end='')
        print(f"{len(events)} events")

# %%
if not RUN_CV:
    rl.to_csv('test_rl.csv')
